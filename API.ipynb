# %%
import requests

# %%
zomato_api_key = 'ff7cb3421dd38689c80851309c89363d'

# %%
parameters = {'res_id': 16774318}
restaurant = requests.get("https://developers.zomato.com/api/v2.1/restaurant", params = parameters, headers = {'user-key': zomato_api_key})

# %%
restaurant
# Out:
# <Response [200]>

# %%
restaurant.url
# Out:
# 'https://developers.zomato.com/api/v2.1/restaurant?res_id=16774318'

# %%
restaurant.text
# Out:
# '{"R":{"has_menu_status":{"delivery":-1,"takeaway":-1},"res_id":16774318,"is_grocery_store":false},"apikey":"ff7cb3421dd38689c80851309c89363d","id":"16774318","name":"Otto Enoteca Pizzeria","url":"https:\\/\\/www.zomato.com\\/new-york-city\\/otto-enoteca-pizzeria-greenwich-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1","location":{"address":"One Fifth Avenue at 8th Street, Greenwich Village 10003","locality":"Greenwich Village","city":"New York City","city_id":280,"latitude":"40.7318200000","longitude":"-73.9965400000","zipcode":"10003","country_id":216,"locality_verbose":"Greenwich Village"},"switch_to_order_menu":0,"cuisines":"Pizza, Italian","timings":"12 Noon to 11 PM (Mon-Thu), 11:30 AM to 12 Midnight (Fri-Sat), 11:30 AM to 11 PM (Sun)","average_cost_for_two":40,"price_range":3,"currency":"$","highlights":["Serves Alcohol","Delivery","Lunch","Dinner","Takeaway Available","Credit Card","Vegetarian Friendly","Fullbar","Table booking recommended","Indoor Seatin
# ...

# %%
restaurant.json()
# Out:
# {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#   'res_id': 16774318,
#   'is_grocery_store': False},
#  'apikey': 'ff7cb3421dd38689c80851309c89363d',
#  'id': '16774318',
#  'name': 'Otto Enoteca Pizzeria',
#  'url': 'https://www.zomato.com/new-york-city/otto-enoteca-pizzeria-greenwich-village?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#  'location': {'address': 'One Fifth Avenue at 8th Street, Greenwich Village 10003',
#   'locality': 'Greenwich Village',
#   'city': 'New York City',
#   'city_id': 280,
#   'latitude': '40.7318200000',
#   'longitude': '-73.9965400000',
#   'zipcode': '10003',
#   'country_id': 216,
#   'locality_verbose': 'Greenwich Village'},
#  'switch_to_order_menu': 0,
#  'cuisines': 'Pizza, Italian',
#  'timings': '12 Noon to 11 PM (Mon-Thu), 11:30 AM to 12 Midnight (Fri-Sat), 11:30 AM to 11 PM (Sun)',
#  'average_cost_for_two': 40,
#  'price_range': 3,
#  'currency': '$',
#  'highlights': ['Serves Alcohol',
#   'Delivery',
# ...

# %%
response = restaurant.json()

# %%
type(response)
# Out:
# dict

# %%
response['name']
# Out:
# 'Otto Enoteca Pizzeria'

# %%
parameters = {'q': 'kfc'}
search = requests.get("https://developers.zomato.com/api/v2.1/search", params = parameters, headers = {'user-key': zomato_api_key})

# %%
search
# Out:
# <Response [200]>

# %%
search.json()
# Out:
# {'results_found': 2,
#  'results_start': 0,
#  'results_shown': 2,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': 1,
#       'takeaway': -1},
#      'res_id': 19351562,
#      'is_grocery_store': False},
#     'apikey': 'ff7cb3421dd38689c80851309c89363d',
#     'id': '19351562',
#     'name': 'KFC',
#     'url': 'https://www.zomato.com/trichy/kfc-thillai-nagar?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Shop 3/1, Annamali Tower, New Karur Bypass Road, Annamalai Nagar, Thillai Nagar, Trichy',
#      'locality': 'Thillai Nagar',
#      'city': 'Trichy',
#      'city_id': 11332,
#      'latitude': '10.8278690000',
#      'longitude': '78.6856230000',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Thillai Nagar, Trichy'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Burger, Fast Food, Finger Food, Beverages',
#     'timings': '11am – 10pm (Mon-Sun)',
# ...

# %%
import json
json.loads(search.text)
# Out:
# {'results_found': 2,
#  'results_start': 0,
#  'results_shown': 2,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': 1,
#       'takeaway': -1},
#      'res_id': 19351562,
#      'is_grocery_store': False},
#     'apikey': 'ff7cb3421dd38689c80851309c89363d',
#     'id': '19351562',
#     'name': 'KFC',
#     'url': 'https://www.zomato.com/trichy/kfc-thillai-nagar?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Shop 3/1, Annamali Tower, New Karur Bypass Road, Annamalai Nagar, Thillai Nagar, Trichy',
#      'locality': 'Thillai Nagar',
#      'city': 'Trichy',
#      'city_id': 11332,
#      'latitude': '10.8278690000',
#      'longitude': '78.6856230000',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Thillai Nagar, Trichy'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Burger, Fast Food, Finger Food, Beverages',
#     'timings': '11am – 10pm (Mon-Sun)',
# ...

# %%
# convert dict to json format
example = dict()
example['qw'] = dict()
example['lkj'] = 'mbbvjh'
example['qw']['hgf'] = 'hg'

# %%
json.dumps(example)
# Out:
# '{"qw": {"hgf": "hg"}, "lkj": "mbbvjh"}'

# %%
# convert json string to dictionary
json.loads(json.dumps(example))
# Out:
# {'qw': {'hgf': 'hg'}, 'lkj': 'mbbvjh'}

# %%
# we will work with OAuth type of authentication

# %%
spotify_client_id = '6e2e29f26341434c96d004b79d146bc3'
client_secret = '226915eafef947089e7a80a471742d5a'
url = "https://spotifystefan-skliarovv1.p.rapidapi.com/search"
AUTH_URL = 'https://accounts.spotify.com/api/token'
BASE_URL = 'https://api.spotify.com/v1/'

# %%
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': spotify_client_id,
    'client_secret': client_secret,
})

# %%
auth_response_data = auth_response.json()

# %%
auth_response_data
# Out:
# {'access_token': 'BQCBCfbj76dEvRyd4wZsXwiEq5bwJmVjo2OPm8a8zFZDU86S_faFWvQf_yO3NMBlVjaG4-0r_7Azo4CFgf4',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'scope': ''}

# %%
access_token = auth_response_data['access_token']

# %%
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}

# %%
payload = {'ids': '6rqhFgbbKwnb9MLmUQDhG6'}
search = requests.get(BASE_URL+'tracks/', params = payload, headers = headers)

# %%
search
# Out:
# <Response [200]>

# %%
search.json()
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9'},
#       'href': 'https://api.spotify.com/v1/artists/0k17h0D3J5VfsdmQ1iZtE9',
#       'id': '0k17h0D3J5VfsdmQ1iZtE9',
#       'name': 'Pink Floyd',
#       'type': 'artist',
#       'uri': 'spotify:artist:0k17h0D3J5VfsdmQ1iZtE9'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3a0UOgDWw2pTajw85QPMiz'},
#     'href': 'https://api.spotify.com/v1/albums/3a0UOgDWw2pTajw85QPMiz',
#     'id': '3a0UOgDWw2pTajw85QPMiz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27305d4eec40a828850aa8cd2f7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0205d4eec40a828850aa8cd2f7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485105d4eec40a828850aa8cd2f7',
# ...

# %%
payload = {'q': 'harry', 'type': 'album'}
search = requests.get(BASE_URL+'search/', params = payload, headers = headers)

# %%
search.json()
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/search?query=harry&type=album&offset=0&limit=20',
#   'items': [{'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6KImCVD70vtIoJWnq6nGn3'},
#       'href': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3',
#       'id': '6KImCVD70vtIoJWnq6nGn3',
#       'name': 'Harry Styles',
#       'type': 'artist',
#       'uri': 'spotify:artist:6KImCVD70vtIoJWnq6nGn3'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
# ...

# %%
 # https://developer.spotify.com/documentation/web-api/reference/search/search/
